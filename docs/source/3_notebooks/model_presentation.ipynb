# %% [markdown]
# # Presentation of the model and of the implementation work
#
# This section presents some general specifications of the model used, the variables created.

# %%
import pysd
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Models and their damage functions
#
# A full list of damage functions being implemented (or not) can be found in the API Documentation section, along with their python variable names and their VENSIM implementation characteristics. To avoid over-technical descriptions here, we will re-write them in much simpler form here, and curious readers will have a look at the API section.

# %% [markdown]
# ### DICE
#
# Presentation of the DICE function :
#
# $$ D = \alpha_1 \Delta T + \alpha_2 \Delta T^2 $$

# %%
temp_range = np.linspace(0, 6, 1000)
alpha_1 = 0
alpha_2 = 0.003467


plt.plot(temp_range, 100*(alpha_1 * temp_range + (alpha_2 * temp_range)**2))
plt.xlabel('Temperature change compared to pre-industrial conditions')
plt.ylabel('% of yearly damage to GDP')
plt.title('Damages to GDP as a function of temperature change')
plt.show()

# %% [markdown]
# ### WITNESS

# %% [markdown]
# ### DSK

# %% [markdown]
# ### FUND
