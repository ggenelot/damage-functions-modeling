# %%
import wooldridge as woo

# %%
wage1 = woo.dataWoo('wage1')

# %%
wage1
# Out:
#       wage  educ  exper  tenure  nonwhite  female  married  numdep  smsa  \
# 0     3.10    11      2       0         0       1        0       2     1
# 1     3.24    12     22       2         0       1        1       3     1
# 2     3.00    11      2       0         0       0        0       2     0
# 3     6.00     8     44      28         0       0        1       0     1
# 4     5.30    12      7       2         0       0        1       1     0
# ..     ...   ...    ...     ...       ...     ...      ...     ...   ...
# 521  15.00    16     14       2         0       1        1       2     0
# 522   2.27    10      2       0         0       1        0       3     0
# 523   4.67    15     13      18         0       0        1       3     0
# 524  11.56    16      5       1         0       0        1       0     0
# 525   3.50    14      5       4         1       1        0       2     0
#
#      northcen  ...  trcommpu  trade  services  profserv  profocc  clerocc  \
# ...

# %%
import statsmodels.formula.api as smf

# %%
reg = smf.ols(formula='wage ~ educ + exper + tenure + nonwhite + female', data=wage1)
results = reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     59.43
# Date:                Fri, 12 Jul 2024   Prob (F-statistic):           6.48e-49
# Time:                        11:17:19   Log-Likelihood:                -1314.2
# No. Observations:                 526   AIC:                             2640.
# Df Residuals:                     520   BIC:                             2666.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5403      0.732     -2.103      0.036      -2.979      -0.102
# ...

# %%
reg = sm.OLS(wage1['wage'], sm.add_constant(wage1[['educ', 'exper', 'tenure', 'nonwhite', 'female']])).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     59.43
# Date:                Fri, 12 Jul 2024   Prob (F-statistic):           6.48e-49
# Time:                        11:14:52   Log-Likelihood:                -1314.2
# No. Observations:                 526   AIC:                             2640.
# Df Residuals:                     520   BIC:                             2666.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5403      0.732     -2.103      0.036      -2.979      -0.102
# ...
