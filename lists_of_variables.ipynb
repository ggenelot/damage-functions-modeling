# %%
import pandas as pd

# %%
variables = pd.read_csv('variables.csv', index_col=0)

df = pd.DataFrame(columns=['List name', 'Variable names'])

modeled_variables = variables[variables['Model'].notnull()]
modeled_variables_names = modeled_variables["Py Name"].tolist()
modeled_variables_df = pd.DataFrame({'List name': 'modeled_variables', 'Variable names': modeled_variables_names})

df = pd.concat([df, modeled_variables_df])


modeled_variables_names
# Out:
# ['define_46_eq_damage_function',
#  'define_46_eta1',
#  'define_46_eta2',
#  'define_46_eta3',
#  'define_46_exponent',
#  'define_tot_eq_define_total_impact',
#  'dice_5_eq_damage_function',
#  'dice_5_damage_function_phi_1',
#  'dice_5_damage_function_phi2',
#  'dice_6_eq_abatment_function',
#  'dice_6_emissions_control_rate',
#  'dice_6_abatment_theta_1',
#  'dice_6_abatment_theta_2',
#  'dice_tot_eq_dice_total_impact',
#  'dsk_a128_eq_shock_from_climate_change',
#  'dsk_a1291_shock_from_climate_change_param_1',
#  'dsk_a1292_shock_from_climate_change_param_2',
#  'dsk_tot_eq_dsk_total_impact',
#  'extra_extra_gdp_modifyer',
#  'extra_extra_exponent',
#  'extra_extra_normalisation_constant',
#  'fund_a1_eq_total_agricultural_impact',
#  'fund_a2_delayed_agricultural_impact_of_the_rate_of_climate_change',
#  'fund_a2_eq_agricultural_impact_of_the_rate_of_climate_change',
#  'fund_a2_alpha_parameter',
#  'fund_a2_beta_parameter',
#  'fund_a2_rate_of_temperature_change',
# ...
